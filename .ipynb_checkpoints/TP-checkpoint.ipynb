# %%
# Leo el archivo separado por ';'
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('DataSet_Edad-Talla-Peso-TA.csv',sep=';')

# %%
# Mostramos un poco de información del archivo.
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Altura  4901 non-null   object
#  1   Peso    5000 non-null   int64
#  2   Sexo    4910 non-null   object
#  3   Edad    5000 non-null   int64
#  4   PA_max  5000 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 195.4+ KB
#   Altura   Peso Sexo  Edad PA_max
# 0   1,47  53000    M    33   12,3
# 1    172     90    F    28   13,3
# 2    1,6    118    M    77   24,9
# 3   1,76     97    M    52   18,3
# 4   1,81    118    F    73   25,8

# %% [markdown]
# ### CORRECION DE DATOS

# %%
# Las columnas Altura y PA_max deberían ser numericos.
# Entonces convertimos la columna altura y PA en un float.
df['Altura']=df['Altura'].str.replace(',','.').astype(float)
df['PA_max']=df['PA_max'].str.replace(',','.').astype(float)

# %%
df.describe()
# Out:
#             Altura          Peso         Edad       PA_max
# count  4901.000000    5000.00000  5000.000000  5000.000000
# mean      8.013291    1102.30400    47.875000    16.422520
# std      32.148415    8753.19627    17.300833    13.776803
# min       1.450000       0.00000    18.000000     8.400000
# 25%       1.600000      64.00000    33.000000    12.500000
# 50%       1.700000      80.00000    48.000000    14.400000
# 75%       1.820000     104.00000    63.000000    16.900000
# max     226.000000  123000.00000    77.000000   193.000000

# %%
# Removemos datos nulos
# Elimino todas las filas que contienen al menos algun dato nulo
df=df.dropna(axis=0, how='any')
# Pudimos ver con describe que el minimo de 'Peso' es 0, debemos remover esto. 
df=df[df['Peso']!=0]

#df.describe()

# %%
# Elimino outlayers, estos limites los ponemos por criterio propio.
df=df[df['Altura']<3]
df=df[df['Peso']<300]
df=df[df['PA_max']<40]

# Otro cambio que nos parece importante para entrenar luego el modelo, 
# es transformar la columna Sexo, con variables discretas
# en 2 columnas Hombre y Mujer, donde un 1 implicará que la persona es de ese sexo.
df['Hombre']=(df.Sexo=='M').astype(int)
df['Mujer']=(df.Sexo=='F').astype(int)
#df.boxplot(column=['Altura','Peso','Edad','PA_max'],figsize=(30,20),vert=False)

# %%
df.boxplot(column='Altura',vert=False,figsize=(16,2))


# Removemos los valores por fuera de 1.5 interquartiles.

alturaInter = (df.Altura.quantile(q=0.75) - df.Altura.quantile(q=0.25))
alturaMax = df.Altura.quantile(q=0.75) + alturaInter
alturaMin = df.Altura.quantile(q=0.25) - alturaInter
df=df[df['Altura'].between(alturaMin, alturaMax, inclusive=True)]

print(f'Seleccionamos solo los valores entre {round(alturaMin,2)} y {round(alturaMax,2)}')
df.plot(kind='scatter',x='Altura',y='PA_max',figsize=[7,7])
# Out:
# Seleccionamos solo los valores entre 1.4 y 2.0
# <AxesSubplot:xlabel='Altura', ylabel='PA_max'>

# %%
df.boxplot(column='Peso',vert=False,figsize=(16,2))

# Removemos los valores por fuera de 1.5 interquartiles.
pesoInter = (df.Peso.quantile(q=0.75) - df.Peso.quantile(q=0.25))
pesoMax = df.Peso.quantile(q=0.75) + pesoInter
pesoMin = df.Peso.quantile(q=0.25) - pesoInter
df=df[df['Peso'].between(pesoMin, pesoMax, inclusive=True)]

print(f'Seleccionamos solo los valores entre {round(pesoMin,2)} y {round(pesoMax,2)}')
df.plot(kind='scatter',x='Peso',y='PA_max',figsize=[7,7])
# Parece haber una pequeña tendencia a tener mayor PA a mayor peso, pero no es tan clara.
# Esto puede ser poque el Peso esta muy relacionado con la Altura.
# Out:
# Seleccionamos solo los valores entre 27.0 y 138.0
# <AxesSubplot:xlabel='Peso', ylabel='PA_max'>

# %%
df.boxplot(column='PA_max',vert=False,figsize=(16,2))

# Removemos los valores por fuera de 1.5 interquartiles.
paInter = (df.PA_max.quantile(q=0.75) - df.PA_max.quantile(q=0.25))
paMax = df.PA_max.quantile(q=0.75) + paInter
paMin = df.PA_max.quantile(q=0.25) - paInter
df=df[df['PA_max'].between(paMin, paMax, inclusive=True)]

print(f'Seleccionamos solo los valores entre {round(paMin,2)} y {round(paMax,2)}')
# Out:
# Seleccionamos solo los valores entre 8.2 y 20.8

# %%
# Agrego la columna con el IMC (Peso/(Altura**2)) ya que es un dato muy relacionado con la PA.
df['IMC']=df['Peso']/(df['Altura']**2)


# Mostramos el boxplot de IMC
df.boxplot(column='IMC',vert=False,figsize=(16,2))


# Removemos los valores por fuera de 1.5 interquartiles.
imcInter = (df.IMC.quantile(q=0.75) - df.IMC.quantile(q=0.25))
imcMax = df.IMC.quantile(q=0.75) + imcInter
imcMin = df.IMC.quantile(q=0.25) - imcInter
df=df[df['IMC'].between(imcMin, imcMax, inclusive=True)]

print(f'Seleccionamos solo los valores entre {round(imcMin,2)} y {round(imcMax,2)}')
df.plot(kind='scatter',x='IMC',y='PA_max',figsize=[7,7])
# Out:
# Seleccionamos solo los valores entre 14.93 y 37.95
# C:\Users\joni\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <AxesSubplot:xlabel='IMC', ylabel='PA_max'>

# %%
# Mostramos el boxplot de IMC
df.boxplot(column='Edad',vert=False,figsize=(16,2))
df.plot(kind='scatter',x='Edad',y='PA_max',figsize=[8,8])
# Out:
# <AxesSubplot:xlabel='Edad', ylabel='PA_max'>

# %%
# Agrego la columna con el PA transformado en categorias, baja, normal y alta.
#
df['PA_cat']=pd.cut(df['PA_max'], bins=[0,9,12,30], labels=['Baja','Normal','Alta'],right=True)

# %%
# Regresion Lineal
from sklearn import linear_model
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

df2=df.copy()
# Igualamos las escalas de 0 a 1 para luego ver la importancia de cada variable.
# Para eso restamos el valor con el valor minimo y a eso lo dividimos por el rango min-max.
df2['Altura']=(df['Altura']-df['Altura'].min())/(df['Altura'].max()-df['Altura'].min())
df2['Peso']=(df['Peso']-df['Peso'].min())/(df['Peso'].max()-df['Peso'].min())
df2['Edad']=(df['Edad']-df['Edad'].min())/(df['Edad'].max()-df['Edad'].min())
df2['IMC']=(df['IMC']-df['IMC'].min())/(df['IMC'].max()-df['IMC'].min())

#****** PARAMETROS ********
optiondf = 2    # 1 = DF  ///  2 = DF2 (escalas iguales)
X_train_opcion = 0
profundidad=4
#************ *************
# Opciones de X train
X_train_opciones=[['Altura','Peso', 'Hombre','Mujer', 'Edad', 'IMC'], # 0
                  ['Altura','Peso', 'Edad', 'IMC'], # 1
                  ['Hombre','Mujer','Edad', 'IMC'], # 2
                  ['Altura','Peso', 'Edad'] # 3                  
                 ]


#Usar DF normal o usar DF2 (con escalas igualadas)
if optiondf == 1:
    dfmodel = df
elif optiondf == 2:
    dfmodel = df2

df_train, df_test = train_test_split(dfmodel, test_size=0.2)


# Dividimos los dataset en X e Y
# ---------------------------------------------------------------------------------------------
X_train = df_train[X_train_opciones[X_train_opcion]]
y_train = df_train['PA_max']

X_test = df_test[X_train_opciones[X_train_opcion]]
y_test = df_test['PA_max']

# Creacion, entrenamiento y pronostico del modelo Linear Regression
# ---------------------------------------------------------------------------------------------
modelo = linear_model.LinearRegression(fit_intercept=True) 
modelo.fit(X_train,y_train)
y_pred = modelo.predict(X_test)

# Creacion, entrenamiento y pronostico del modelo Tree Regressor
# ---------------------------------------------------------------------------------------------
modeloT = DecisionTreeRegressor(max_depth=profundidad) 
modeloT.fit(X_train,y_train)
y_predT = modeloT.predict(X_test)

# Obtenemos el RMSE
from sklearn.metrics import mean_squared_error, r2_score
RMSE=mean_squared_error(y_test, y_pred)**(1/2)
print('Lineal Regression')
print(f'RMSE: {RMSE}, RMSE/MEDIA= {100*round(RMSE/(df2.PA_max.mean()),2)} %')

from sklearn.metrics import mean_squared_error, r2_score
RMSET=mean_squared_error(y_test, y_predT)**(1/2)
print('Tree Regressor')
print(f'RMSE: {RMSET}, RMSE/MEDIA= {100*round(RMSET/(df2.PA_max.mean()),2)} %')
# Out:
# Lineal Regression
# RMSE: 2.308975501789708, RMSE/MEDIA= 16.0 %
# Tree Regressor
# RMSE: 2.2990629635388395, RMSE/MEDIA= 16.0 %

# %%
from sklearn.tree import DecisionTreeClassifier

#Parametro de profundidad
profundidad=4

# Seleccionamos el el PA con categorias para el Y.
# ---------------------------------------------------------------------------------------------
X_train = df_train[X_train_opciones[X_train_opcion]]
y_train2 = df_train['PA_cat']

X_test = df_test[X_train_opciones[X_train_opcion]]
y_test2 = df_test['PA_cat']

# Creacion, entrenamiento y pronostico del modelo.
# ---------------------------------------------------------------------------------------------
modelo2 = DecisionTreeClassifier(max_depth=profundidad)
modelo2.fit(X_train,y_train2)
y_pred2 = modelo2.predict(X_test)

# Obtenemos el RMSE
from sklearn.metrics import accuracy_score, f1_score
AC=accuracy_score(y_test2, y_pred2)
F1=f1_score(y_test2,y_pred2, average='macro')  # average='macro' --> y tiene más de una etiqueta.
print("Evaluación modelo Árbol de Decisión")
print("Accuracy: ", round(AC,3))
print("F1: ", round(F1,3))
# Out:
# Evaluación modelo Árbol de Decisión
# Accuracy:  0.779
# F1:  0.415

# %%
# IMPORTANCIA DE CADA VARIABLE  
# Usaremos los resultados del modelo de Linear Regression.
print('df',optiondf)
                                      #coef             #media
if optiondf == 1:
    plt.plot(X_train.columns,      modelo.coef_ * df.describe()[X_train.columns].iloc[1]  )
elif optiondf == 2:
    plt.plot(X_train.columns,      modelo.coef_ )
    
#medias
#df.describe()[X_train.columns].iloc[5]
#df[df.columns[0]].mean()
#modelo.coef_[3]*df.IMC.mean()
# La edad parece estar en primer lugar, seguido por el Peso.
# La altura tambien parece influir negativamente en la presion arterial pero esto
# puede ser para compensar el Peso de la persona.
# el IMC afecta con un poco menos de importancia.
# Out:
# df 2

# %%
from pandas.plotting import radviz

# Copiamos las columnas a utilizar desde lo que usamos en el train de los modelos
radvizcolumns=X_train_opciones[X_train_opcion].copy()

# Seteamos el PA a utilizar como Y
radvizcolumns.append('PA_cat')
#radvizcolumns.append('PA_max')

# Removemos las columnas que no son importantes
radvizcolumns.remove('Hombre')
radvizcolumns.remove('Mujer')
#radvizcolumns.remove('Altura')
#radvizcolumns.remove('Peso')
radvizcolumns.remove('IMC')


# Graficamos
fig, ax = plt.subplots()
fig.set_size_inches(10, 10)
pd.plotting.radviz(frame=df[radvizcolumns], 
                   class_column='PA_cat', 
                   color=['red','lightblue','green'], ax=ax)


# Este grafico "atrae" a los puntos segun el valor de la variable,
# Por ejemplo, si un punto esta más cerca de "IMC", 
# significa que para es punto su IMC es mayor al resto de variables.
# Out:
# <AxesSubplot:>
